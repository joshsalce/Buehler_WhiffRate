# %%
# %pip install pybaseball -q
# Out:
#      |████████████████████████████████| 415 kB 5.4 MB/s
#      |████████████████████████████████| 291 kB 24.3 MB/s
#      |████████████████████████████████| 856 kB 48.0 MB/s

# %%
import pybaseball as pyb
from pybaseball import statcast
from pybaseball import statcast_pitcher, playerid_lookup
from pybaseball import pitching_stats_bref
import pandas as pd
import numpy as np

# %%
playerid_lookup('buehler','walker')['key_mlbam'][0]
621111
# Out:
# Gathering player lookup table. This may take a moment.
# 621111

# %%
buehler21 = statcast_pitcher('2021-04-01', '2021-10-03', player_id = 621111)
# Out:
# Gathering Player Data

# %%
hard_hit_4seam = buehler21[(buehler21['description'] == "hit_into_play") & 
                           (buehler21["pitch_type"] == "FF") & 
                           (buehler21['launch_speed'] >= 95.0)]
hard_hit_4seam
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 26           FF  2021-10-03           95.1          -0.91           5.76
# 31           FF  2021-10-03           95.7          -0.48           5.78
# 105          FF  2021-09-28           93.9          -1.09           5.68
# 119          FF  2021-09-28           95.1          -0.43           5.83
# 152          FF  2021-09-28           95.2          -0.90           5.69
# ...         ...         ...            ...            ...            ...
# 3088         FF  2021-04-03           94.9          -0.99           5.73
# 3097         FF  2021-04-03           95.6          -0.91           5.76
# 3102         FF  2021-04-03           94.8          -1.02           5.64
# 3137         FF  2021-04-03           94.2          -1.16           5.72
# 3138         FF  2021-04-03           95.5          -1.00           5.71
#
#           player_name  batter  pitcher     events    description  ...  \
# ...

# %%
four_seam_batted = buehler21[(buehler21['description'] == "hit_into_play") & (buehler21["pitch_type"] == "FF")]
four_seam_batted
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 26           FF  2021-10-03           95.1          -0.91           5.76
# 31           FF  2021-10-03           95.7          -0.48           5.78
# 90           FF  2021-09-28           95.0          -0.71           5.75
# 103          FF  2021-09-28           94.4          -0.65           5.88
# 105          FF  2021-09-28           93.9          -1.09           5.68
# ...         ...         ...            ...            ...            ...
# 3130         FF  2021-04-03           95.9          -1.22           5.61
# 3136         FF  2021-04-03           94.4          -1.06           5.80
# 3137         FF  2021-04-03           94.2          -1.16           5.72
# 3138         FF  2021-04-03           95.5          -1.00           5.71
# 3149         FF  2021-04-03           94.7          -1.22           5.74
#
#           player_name  batter  pitcher                     events  \
# ...

# %% [markdown]
# 99/216 = 0.4583

# %% [markdown]
# Walker Buehler 2022 Hard-Hit Rate

# %%
buehler22 = statcast_pitcher('2022-03-21', '2022-6-11', player_id = 621111)
# Out:
# Gathering Player Data

# %%
hard_hit_2022 = buehler22[(buehler22['description'] == "hit_into_play") & 
                           (buehler22["pitch_type"] == "FF") & 
                           (buehler22['launch_speed'] > 95.0)]
hard_hit_2022
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            FF  2022-06-10           94.8          -1.09           5.43
# 48           FF  2022-06-10           97.4          -0.84           5.68
# 54           FF  2022-06-10           96.9          -0.63           5.73
# 101          FF  2022-06-04           97.0          -1.02           5.48
# 109          FF  2022-06-04           93.8          -0.95           5.47
# 164          FF  2022-05-30           94.2          -1.23           5.56
# 186          FF  2022-05-30           94.9          -1.28           5.54
# 200          FF  2022-05-30           95.8          -1.49           5.44
# 226          FF  2022-05-30           95.3          -1.77           5.53
# 244          FF  2022-05-24           94.8          -0.71           5.61
# 292          FF  2022-05-24           95.0          -1.07           5.45
# 306          FF  2022-05-24           96.1          -1.25           5.38
# ...

# %%
all_batted = buehler22[(buehler22['description'] == "hit_into_play") & 
                           (buehler22["pitch_type"] == "FF")]
all_batted
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            FF  2022-06-10           94.8          -1.09           5.43
# 32           FF  2022-06-10           95.8          -0.84           5.69
# 38           FF  2022-06-10           95.8          -0.70           5.77
# 48           FF  2022-06-10           97.4          -0.84           5.68
# 54           FF  2022-06-10           96.9          -0.63           5.73
# ...         ...         ...            ...            ...            ...
# 1101         FF  2022-04-03           94.0          -0.76           5.69
# 1102         FF  2022-04-03           93.0          -0.99           5.69
# 1103         FF  2022-04-03           95.6          -0.78           5.64
# 1109         FF  2022-04-03           96.4          -0.82           5.70
# 1123         FF  2022-04-03           95.1          -0.81           5.72
#
#           player_name  batter  pitcher     events    description  ...  \
# ...

# %%
41/75
# Out:
# 0.5466666666666666

# %% [markdown]
# EARLY CAREER

# %%
buehler = statcast_pitcher('2018-03-23', '2020-09-27', player_id = 621111)
# Out:
# Gathering Player Data

# %%
hh_2018_2020 = buehler[(buehler['description'] == "hit_into_play") & 
                           (buehler["pitch_type"] == "FF") & 
                           (buehler['launch_speed'] > 95.0)]
hh_2018_2020
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 75           FF  2020-09-08           98.9          -1.14           5.70
# 120          FF  2020-09-08           99.5          -0.87           5.95
# 163          FF  2020-09-02           96.4          -0.66           5.77
# 206          FF  2020-08-21           97.1          -0.92           5.74
# 335          FF  2020-08-15           96.5          -1.06           5.84
# ...         ...         ...            ...            ...            ...
# 5768         FF  2018-05-21           95.9          -0.91           6.04
# 5815         FF  2018-05-21           96.0          -0.87           5.99
# 5936         FF  2018-05-10           96.6          -1.25           5.92
# 6229         FF  2018-04-23           95.3          -1.02           6.01
# 6246         FF  2018-04-23           97.0          -1.07           5.81
#
#           player_name  batter  pitcher     events    description  ...  \
# ...

# %%
early_batted = buehler[(buehler['description'] == "hit_into_play") & 
                           (buehler["pitch_type"] == "FF")]
early_batted
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 54           FF  2020-09-24           97.2          -0.59           5.93
# 68           FF  2020-09-08           99.8          -0.73           5.93
# 75           FF  2020-09-08           98.9          -1.14           5.70
# 83           FF  2020-09-08           98.7          -0.67           5.84
# 120          FF  2020-09-08           99.5          -0.87           5.95
# ...         ...         ...            ...            ...            ...
# 6220         FF  2018-04-23           95.2          -0.91           5.90
# 6229         FF  2018-04-23           95.3          -1.02           6.01
# 6238         FF  2018-04-23           98.1          -1.04           5.91
# 6246         FF  2018-04-23           97.0          -1.07           5.81
# 6290         FF  2018-04-23           97.9          -1.21           5.96
#
#           player_name  batter  pitcher     events    description  ...  \
# ...

# %%
(144/385) * 100
# Out:
# 37.4025974025974

# %%
buehler['events'].unique()
# Out:
# array(['strikeout', nan, 'walk', 'field_out', 'grounded_into_double_play',
#        'single', 'home_run', 'force_out', 'field_error', 'double',
#        'hit_by_pitch', 'double_play', 'sac_fly', 'triple',
#        'fielders_choice', 'fielders_choice_out', 'sac_bunt',
#        'caught_stealing_2b'], dtype=object)

# %%
buehler['description'].unique()
# Out:
# array(['swinging_strike', 'ball', 'foul', 'blocked_ball', 'hit_into_play',
#        'called_strike', 'foul_tip', 'swinging_strike_blocked',
#        'hit_by_pitch', 'foul_bunt', 'missed_bunt'], dtype=object)

# %%
whiffs = ['swinging_strike_blocked','swinging_strike', 'foul_tip']
swings = ['foul','hit_into_play','foul_tip', 'swinging_strike_blocked','swinging_strike']

# %%
whiff_data = buehler21[(buehler21['description'].isin(whiffs)) & (buehler21["pitch_type"] == "FF")]
whiff_data
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 6            FF  2021-10-03           95.9          -0.64           5.79
# 53           FF  2021-10-03           96.0          -0.90           5.56
# 66           FF  2021-10-03           96.1          -0.75           5.79
# 132          FF  2021-09-28           95.5          -0.98           5.73
# 137          FF  2021-09-28           94.9          -0.58           5.93
# ...         ...         ...            ...            ...            ...
# 3076         FF  2021-04-03           95.1          -0.78           5.71
# 3123         FF  2021-04-03           95.5          -1.30           5.67
# 3126         FF  2021-04-03           95.6          -1.02           5.65
# 3128         FF  2021-04-03           96.0          -0.95           5.68
# 3142         FF  2021-04-03           95.4          -0.82           5.96
#
#           player_name  batter  pitcher     events      description  ...  \
# ...

# %%
swings_data = buehler21[(buehler21['description'].isin(swings)) & (buehler21["pitch_type"] == "FF")]
swings_data
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 6            FF  2021-10-03           95.9          -0.64           5.79
# 11           FF  2021-10-03           94.9          -1.19           5.51
# 26           FF  2021-10-03           95.1          -0.91           5.76
# 29           FF  2021-10-03           95.4          -1.06           5.73
# 31           FF  2021-10-03           95.7          -0.48           5.78
# ...         ...         ...            ...            ...            ...
# 3138         FF  2021-04-03           95.5          -1.00           5.71
# 3141         FF  2021-04-03           95.5          -0.75           5.98
# 3142         FF  2021-04-03           95.4          -0.82           5.96
# 3145         FF  2021-04-03           95.5          -0.82           5.85
# 3149         FF  2021-04-03           94.7          -1.22           5.74
#
#           player_name  batter  pitcher     events      description  ...  \
# ...

# %%
whiffs22 = buehler22[(buehler22['description'].isin(whiffs)) & (buehler22["pitch_type"] == "FF")]
whiffs22
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 15           FF  2022-06-10           94.0          -1.01           5.64
# 24           FF  2022-06-10           95.0          -1.09           5.54
# 66           FF  2022-06-10           96.2          -0.79           5.67
# 110          FF  2022-06-04           95.9          -0.93           5.57
# 321          FF  2022-05-18           95.3          -0.83           5.67
# 325          FF  2022-05-18           95.7          -0.91           5.34
# 358          FF  2022-05-18           94.8          -0.65           5.71
# 372          FF  2022-05-18           96.0          -0.72           5.54
# 406          FF  2022-05-18           95.5          -0.77           5.60
# 550          FF  2022-05-08           96.5          -0.57           5.62
# 591          FF  2022-05-01           94.6          -0.59           5.76
# 602          FF  2022-05-01           93.7          -0.98           5.62
# ...

# %%
swings22 = buehler22[(buehler22['description'].isin(swings)) & (buehler22["pitch_type"] == "FF")]
swings22
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            FF  2022-06-10           94.8          -1.09           5.43
# 6            FF  2022-06-10           93.7          -0.94           5.66
# 15           FF  2022-06-10           94.0          -1.01           5.64
# 23           FF  2022-06-10           95.4          -1.04           5.60
# 24           FF  2022-06-10           95.0          -1.09           5.54
# ...         ...         ...            ...            ...            ...
# 1103         FF  2022-04-03           95.6          -0.78           5.64
# 1107         FF  2022-04-03           95.5          -0.85           5.59
# 1109         FF  2022-04-03           96.4          -0.82           5.70
# 1123         FF  2022-04-03           95.1          -0.81           5.72
# 1124         FF  2022-04-03           95.5          -0.74           5.83
#
#           player_name  batter  pitcher     events      description  ...  \
# ...

# %% [markdown]
# Early Career Whiff Rate

# %%
whiffs_early = buehler[(buehler['description'].isin(whiffs)) & (buehler["pitch_type"] == "FF")]
whiffs_early
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            FF  2020-09-24           97.4          -0.88           5.83
# 19           FF  2020-09-24           97.2          -0.75           5.85
# 28           FF  2020-09-24           97.1          -0.66           6.01
# 29           FF  2020-09-24           97.4          -0.70           5.83
# 40           FF  2020-09-24           98.1          -0.86           5.70
# ...         ...         ...            ...            ...            ...
# 6145         FF  2018-04-28           93.9          -1.20           6.04
# 6152         FF  2018-04-28           97.0          -1.14           5.96
# 6193         FF  2018-04-28           96.5          -1.08           6.05
# 6260         FF  2018-04-23           97.0          -0.99           6.07
# 6264         FF  2018-04-23           96.4          -0.95           5.95
#
#           player_name  batter  pitcher     events      description  ...  \
# ...

# %%
swings_early = buehler[(buehler['description'].isin(swings)) & (buehler["pitch_type"] == "FF")]
swings_early
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            FF  2020-09-24           97.4          -0.88           5.83
# 2            FF  2020-09-24           97.7          -1.02           5.66
# 3            FF  2020-09-24           96.9          -1.19           5.67
# 7            FF  2020-09-24           97.7          -0.89           5.68
# 8            FF  2020-09-24           97.6          -0.82           5.80
# ...         ...         ...            ...            ...            ...
# 6269         FF  2018-04-23           97.7          -1.19           5.82
# 6278         FF  2018-04-23           99.5          -1.14           6.03
# 6280         FF  2018-04-23           98.2          -1.11           5.92
# 6286         FF  2018-04-23           99.1          -1.13           5.95
# 6290         FF  2018-04-23           97.9          -1.21           5.96
#
#           player_name  batter  pitcher     events      description  ...  \
# ...

# %%
100* (368/1377) # Whiff Rate
# Out:
# 26.724763979665937
